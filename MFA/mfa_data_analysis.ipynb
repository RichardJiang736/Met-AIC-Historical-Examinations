# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_column', 0)

# %%
mfa_data = pd.read_csv('Dataset _ Museum of Fine Arts Boston Enhanced Provenance Research NEPIP PUBLIC  - MFA NEPIP.csv')
print(mfa_data.columns)
print(mfa_data.shape)
mfa_data.head()
# Out:
# Index(['Selection', 'Source', 'RetrievalDate', 'Source Url', 'Title', 'Artist',
#        'Url', 'Culture', 'Date', 'Technique', 'Dimensions', 'Acc Num', 'View',
#        'Credit Line', 'Collections', 'Classification', 'Description',
#        'Provenance'],
#       dtype='object')
# (742, 18)
#   Selection  ...                                         Provenance
# 0     NEPIP  ...  1872, Durnovo Family, Moscow, 1872, given by t...
# 1     NEPIP  ...  November 27, 1981, anonymous sale, Christie's,...
# 2     NEPIP  ...  By 1965, de Corbiac family, Lembras, France;fr...
# 3     NEPIP  ...  By the early 1940s, anonymous dealer, Paris, s...
# 4     NEPIP  ...  By 1965 Mrs. Edward Jackson Holmes (Mary Stacy...
#
# [5 rows x 18 columns]
